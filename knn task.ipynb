# %%
import pandas as pd

d = pd.read_csv("tamilmusic_directors_toptracks.csv")

print(d)
# Out:
#     artist_name                                         track_name  \
# 0     Ilayaraja  Ooru Sanam Thoongidichu (From "Mella Thirandha...
# 1     Ilayaraja                       Oru Naalum (From "Ejjaman" )
# 2     Ilayaraja                Aalappol Velappol (From "Ejjaman" )
# 3     Ilayaraja  Nila Kayuthu Neram Nalla Neram (From "Sakalaka...
# 4     Ilayaraja                Naanaga Naanillai Thaye (Version 1)
# ..          ...                                                ...
# 135      Thaman                                  Kalasala Kalasala
# 136      Thaman                     Tum Tum (From "Enemy - Tamil")
# 137      Thaman                                         Dum Masala
# 138      Thaman           Hungry Cheetah (From "They Call Him OG")
# 139      Thaman          Bimbilikki Pilapi (From "Prince ")(Tamil)
#
#      popularity  duration_ms  \
# 0            19       278400
# 1             2       359026
# 2             1       304848
# 3            47       272760
# ...

# %%
print(d.columns)
# Out:
# Index(['artist_name', 'track_name', 'popularity', 'duration_ms', 'album',
#        'release_date', 'collaborating_artist', 'explicit', 'number_of_markets',
#        'available_markets'],
#       dtype='object')

# %%
print(d.isnull().sum())
# Out:
# artist_name               0
# track_name                0
# popularity                0
# duration_ms               0
# album                     0
# release_date              0
# collaborating_artist     12
# explicit                  0
# number_of_markets       140
# available_markets       140
# dtype: int64

# %%
print(d.duplicated().sum())
# Out:
# 0

# %%
print(d.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 140 entries, 0 to 139
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   artist_name           140 non-null    object
#  1   track_name            140 non-null    object
#  2   popularity            140 non-null    int64
#  3   duration_ms           140 non-null    int64
#  4   album                 140 non-null    object
#  5   release_date          140 non-null    object
#  6   collaborating_artist  128 non-null    object
#  7   explicit              140 non-null    bool
#  8   number_of_markets     0 non-null      float64
#  9   available_markets     0 non-null      float64
# dtypes: bool(1), float64(2), int64(2), object(5)
# memory usage: 10.1+ KB
# None

# %%
nd = d.select_dtypes(include=["int64", "float64"])
print(nd)
# Out:
#      popularity  duration_ms  number_of_markets  available_markets
# 0            19       278400                NaN                NaN
# 1             2       359026                NaN                NaN
# 2             1       304848                NaN                NaN
# 3            47       272760                NaN                NaN
# 4            48       272493                NaN                NaN
# ..          ...          ...                ...                ...
# 135          63       251813                NaN                NaN
# 136          62       228567                NaN                NaN
# 137          57       206830                NaN                NaN
# 138          62       119052                NaN                NaN
# 139          60       247000                NaN                NaN
#
# [140 rows x 4 columns]

# %%
print(nd.corr())
# Out:
#                    popularity  duration_ms  number_of_markets  \
# popularity           1.000000    -0.094051                NaN
# duration_ms         -0.094051     1.000000                NaN
# number_of_markets         NaN          NaN                NaN
# available_markets         NaN          NaN                NaN
#
#                    available_markets
# popularity                       NaN
# duration_ms                      NaN
# number_of_markets                NaN
# available_markets                NaN

# %%
from sklearn.neighbors import NearestNeighbors

# %%
print(d.columns.tolist())
# Out:
# ['artist_name', 'track_name', 'popularity', 'duration_ms', 'album', 'release_date', 'collaborating_artist', 'explicit', 'number_of_markets', 'available_markets']
