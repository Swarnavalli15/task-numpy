# %%
import re

# %%
pip install regex
# Out:
# Requirement already satisfied: regex in c:\users\swarn\anaconda3\lib\site-packages (2022.7.9)
# Note: you may need to restart the kernel to use updated packages.

# %%
a="hello this data science class,contact this number 9874651230"
b=r"\d+"
b
# Out:
# '\\d+'

# %%
c=re.search(b,a)
c
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 c=re.search(b,a)
#       2 c
#
# NameError: name 're' is not defined

# %%
import re
text="the order number is 987654"
pattern=r"\d+"
match=re.search(pattern,text)
if match:
    print("found:",match.group())
# Out:
# found: 987654

# %%
c=re.compile("ab.")
d=c.findall(("abcabbaabbbb"))
d
# Out:
# ['abc', 'abb', 'abb']

# %%
c1=re.sub("a","**","data science")
c1
# Out:
# 'd**t** science'

# %%
c=re.match(r"hello",a)
c.group()
# Out:
# 'hello'
