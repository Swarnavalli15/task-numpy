# %%
import pandas as pd

# %%
i=pd.read_csv("ipl_comprehensive_dataset.csv")
i
# Out:
#                  event_name   season  match_number        date  \
# 0     Indian Premier League  2007/08           1.0  2008-04-18
# 1     Indian Premier League  2007/08           2.0  2008-04-19
# 2     Indian Premier League  2007/08           3.0  2008-04-19
# 3     Indian Premier League  2007/08           4.0  2008-04-20
# 4     Indian Premier League  2007/08           5.0  2008-04-20
# ...                     ...      ...           ...         ...
# 1238  Indian Premier League     2026          70.0  2026-05-24
# 1239  Indian Premier League     2026           NaN  2026-05-26
# 1240  Indian Premier League     2026           NaN  2026-05-27
# 1241  Indian Premier League     2026           NaN  2026-05-29
# 1242  Indian Premier League     2026           NaN  2026-05-31
#
#                 city                                              venue  \
# 0          Bangalore                              M Chinnaswamy Stadium
# ...

# %%
i.shape
# Out:
# (1243, 31)

# %%
i.columns
# Out:
# Index(['event_name', 'season', 'match_number', 'date', 'city', 'venue',
#        'team1', 'team2', 'toss_winner', 'toss_decision', 'team1_runs',
#        'team1_wickets', 'team2_runs', 'team2_wickets', 'winner', 'result_type',
#        'win_by_runs', 'win_by_wickets', 'player_of_match', 'match_referee',
#        'umpire1', 'umpire2', 'tv_umpire', 'reserve_umpire', 'match_type',
#        'overs_limit', 'balls_per_over', 'gender', 'team_type', 'team1_players',
#        'team2_players'],
#       dtype='object')

# %%
i.head()
# Out:
#               event_name   season  match_number        date        city  \
# 0  Indian Premier League  2007/08           1.0  2008-04-18   Bangalore
# 1  Indian Premier League  2007/08           2.0  2008-04-19  Chandigarh
# 2  Indian Premier League  2007/08           3.0  2008-04-19       Delhi
# 3  Indian Premier League  2007/08           4.0  2008-04-20     Kolkata
# 4  Indian Premier League  2007/08           5.0  2008-04-20      Mumbai
#
#                                         venue                        team1  \
# 0                       M Chinnaswamy Stadium  Royal Challengers Bangalore
# 1  Punjab Cricket Association Stadium, Mohali              Kings XI Punjab
# 2                            Feroz Shah Kotla             Delhi Daredevils
# 3                                Eden Gardens        Kolkata Knight Riders
# 4                            Wankhede Stadium               Mumbai Indians
#
#                          team2                  toss_winner toss_decision  \
# ...

# %%
i.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1243 entries, 0 to 1242
# Data columns (total 31 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   event_name       1243 non-null   object
#  1   season           1243 non-null   object
#  2   match_number     1169 non-null   float64
#  3   date             1243 non-null   object
#  4   city             1243 non-null   object
#  5   venue            1243 non-null   object
#  6   team1            1243 non-null   object
#  7   team2            1243 non-null   object
#  8   toss_winner      1243 non-null   object
#  9   toss_decision    1243 non-null   object
#  10  team1_runs       1243 non-null   int64
#  11  team1_wickets    1243 non-null   int64
#  12  team2_runs       1243 non-null   int64
#  13  team2_wickets    1243 non-null   int64
#  14  winner           1243 non-null   object
#  15  result_type      1243 non-null   object
#  16  win_by_runs      1243 non-null   int64
# ...

# %%
i.describe()
# Out:
#        match_number   team1_runs  team1_wickets   team2_runs  team2_wickets  \
# count   1169.000000  1243.000000    1243.000000  1243.000000    1243.000000
# mean      31.921300   165.851167       5.956557   157.349155       5.873693
# std       18.626023    35.490847       2.309341    34.613073       2.646538
# min        1.000000     2.000000       0.000000     0.000000       0.000000
# 25%       16.000000   144.000000       4.000000   138.000000       4.000000
# 50%       32.000000   165.000000       6.000000   160.000000       6.000000
# 75%       47.000000   189.000000       8.000000   179.000000       8.000000
# max       72.000000   287.000000      10.000000   265.000000      12.000000
#
#        win_by_runs  win_by_wickets  overs_limit  balls_per_over
# count  1243.000000     1243.000000       1243.0          1243.0
# mean     13.932422        3.276750         20.0             6.0
# std      23.861556        3.358216          0.0             0.0
# ...

# %%
#missing
i.isnull().sum()
# Out:
# event_name          0
# season              0
# match_number       74
# date                0
# city                0
# venue               0
# team1               0
# team2               0
# toss_winner         0
# toss_decision       0
# team1_runs          0
# team1_wickets       0
# team2_runs          0
# team2_wickets       0
# winner              0
# result_type         0
# win_by_runs         0
# win_by_wickets      0
# player_of_match     0
# match_referee       0
# umpire1             0
# umpire2             0
# tv_umpire           0
# reserve_umpire      0
# match_type          0
# overs_limit         0
# balls_per_over      0
# gender              0
# team_type           0
# team1_players       0
# team2_players       0
# dtype: int64

# %%
i.duplicated().sum()
# Out:
# 0

# %%
i['season'].value_counts().sort_index()
# Out:
# 2007/08    58
# 2009       57
# 2009/10    60
# 2011       73
# 2012       74
# 2013       76
# 2014       60
# 2015       59
# 2016       60
# 2017       59
# 2018       60
# 2019       60
# 2020/21    60
# 2021       60
# 2022       74
# 2023       74
# 2024       71
# 2025       74
# 2026       74
# Name: season, dtype: int64

# %%
import seaborn as sns
sns.countplot(i['season'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 2
#       1 import seaborn as sns
# ----> 2 sns.countplot(i['season'])
#
# File ~\anaconda3\Lib\site-packages\seaborn\categorical.py:2943, in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, ax, **kwargs)
#    2940 elif x is not None and y is not None:
#    2941     raise ValueError("Cannot pass values for both `x` and `y`")
# -> 2943 plotter = _CountPlotter(
#    2944     x, y, hue, data, order, hue_order,
#    2945     estimator, errorbar, n_boot, units, seed,
#    2946     orient, color, palette, saturation,
#    2947     width, errcolor, errwidth, capsize, dodge
#    2948 )
#    2950 plotter.value_label = "count"
#    2952 if ax is None:
#
# ...

# %%
#team analysis
i['team1'].value_counts()
# Out:
# Chennai Super Kings            142
# Mumbai Indians                 139
# Royal Challengers Bangalore    135
# Kolkata Knight Riders          134
# Rajasthan Royals               115
# Sunrisers Hyderabad            104
# Kings XI Punjab                 92
# Delhi Daredevils                85
# Delhi Capitals                  52
# Punjab Kings                    47
# Lucknow Super Giants            41
# Deccan Chargers                 39
# Gujarat Titans                  34
# Royal Challengers Bengaluru     24
# Pune Warriors                   23
# Gujarat Lions                   16
# Rising Pune Supergiant           7
# Rising Pune Supergiants          7
# Kochi Tuskers Kerala             7
# Name: team1, dtype: int64

# %%
#winner
i['winner'].value_counts()
# Out:
# Mumbai Indians                 155
# Chennai Super Kings            148
# Kolkata Knight Riders          140
# Rajasthan Royals               123
# Royal Challengers Bangalore    114
# Sunrisers Hyderabad            102
# Kings XI Punjab                 85
# Delhi Daredevils                67
# Delhi Capitals                  58
# Gujarat Titans                  47
# Punjab Kings                    41
# Lucknow Super Giants            34
# Royal Challengers Bengaluru     29
# Deccan Chargers                 29
# None                            25
# Gujarat Lions                   13
# Pune Warriors                   12
# Rising Pune Supergiant          10
# Kochi Tuskers Kerala             6
# Rising Pune Supergiants          5
# Name: winner, dtype: int64

# %%
i['winner'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
i['toss_winner'].value_counts()
# Out:
# Mumbai Indians                 160
# Rajasthan Royals               137
# Kolkata Knight Riders          135
# Chennai Super Kings            133
# Royal Challengers Bangalore    113
# Sunrisers Hyderabad            100
# Kings XI Punjab                 85
# Delhi Daredevils                80
# Delhi Capitals                  68
# Punjab Kings                    44
# Deccan Chargers                 43
# Gujarat Titans                  36
# Lucknow Super Giants            30
# Royal Challengers Bengaluru     23
# Pune Warriors                   20
# Gujarat Lions                   15
# Kochi Tuskers Kerala             8
# Rising Pune Supergiants          7
# Rising Pune Supergiant           6
# Name: toss_winner, dtype: int64

# %%
#wicket
i['team1_wickets'].value_counts().sort_index()
# Out:
# 0       5
# 1      24
# 2      50
# 3     108
# 4     168
# 5     195
# 6     186
# 7     157
# 8     146
# 9     114
# 10     90
# Name: team1_wickets, dtype: int64

# %%
i['player_of_match'].value_counts().head(10).plot(kind="bar")
# Out:
# <Axes: >

# %%
tm=i[i["result_type"]=="tie"]
tm
# Out:
#                  event_name   season  match_number        date       city  \
# 66    Indian Premier League     2009          10.0  2009-04-23  Cape Town
# 130   Indian Premier League  2009/10          16.0  2010-03-21    Chennai
# 328   Indian Premier League     2013           7.0  2013-04-07  Hyderabad
# 342   Indian Premier League     2013          21.0  2013-04-16  Bangalore
# 416   Indian Premier League     2014          19.0  2014-04-29  Abu Dhabi
# 475   Indian Premier League     2015          18.0  2015-04-21  Ahmedabad
# 610   Indian Premier League     2017          35.0  2017-04-29     Rajkot
# 705   Indian Premier League     2019          10.0  2019-03-30      Delhi
# 746   Indian Premier League     2019          51.0  2019-05-02     Mumbai
# 757   Indian Premier League  2020/21           2.0  2020-09-20    Unknown
# 765   Indian Premier League  2020/21          10.0  2020-09-28    Unknown
# 790   Indian Premier League  2020/21          35.0  2020-10-18  Abu Dhabi
# ...

# %%
i.columns
# Out:
# Index(['event_name', 'season', 'match_number', 'date', 'city', 'venue',
#        'team1', 'team2', 'toss_winner', 'toss_decision', 'team1_runs',
#        'team1_wickets', 'team2_runs', 'team2_wickets', 'winner', 'result_type',
#        'win_by_runs', 'win_by_wickets', 'player_of_match', 'match_referee',
#        'umpire1', 'umpire2', 'tv_umpire', 'reserve_umpire', 'match_type',
#        'overs_limit', 'balls_per_over', 'gender', 'team_type', 'team1_players',
#        'team2_players'],
#       dtype='object')

# %%
wi=i['winner'].value_counts()
wi
# Out:
# Mumbai Indians                 155
# Chennai Super Kings            148
# Kolkata Knight Riders          140
# Rajasthan Royals               123
# Royal Challengers Bangalore    114
# Sunrisers Hyderabad            102
# Kings XI Punjab                 85
# Delhi Daredevils                67
# Delhi Capitals                  58
# Gujarat Titans                  47
# Punjab Kings                    41
# Lucknow Super Giants            34
# Royal Challengers Bengaluru     29
# Deccan Chargers                 29
# None                            25
# Gujarat Lions                   13
# Pune Warriors                   12
# Rising Pune Supergiant          10
# Kochi Tuskers Kerala             6
# Rising Pune Supergiants          5
# Name: winner, dtype: int64

# %%
mp=pd.concat([i["team1"],i["team2"]]).value_counts()
mp
# Out:
# Mumbai Indians                 291
# Kolkata Knight Riders          278
# Chennai Super Kings            266
# Rajasthan Royals               251
# Royal Challengers Bangalore    240
# Sunrisers Hyderabad            211
# Kings XI Punjab                190
# Delhi Daredevils               161
# Delhi Capitals                 120
# Punjab Kings                    88
# Gujarat Titans                  77
# Deccan Chargers                 75
# Lucknow Super Giants            72
# Pune Warriors                   46
# Royal Challengers Bengaluru     46
# Gujarat Lions                   30
# Rising Pune Supergiant          16
# Rising Pune Supergiants         14
# Kochi Tuskers Kerala            14
# dtype: int64
