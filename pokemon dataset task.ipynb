# %%
import pandas as pd

# %%
#load dataset
df= pd.read_csv("pokemon_complete.csv")

# %%
#display first 5 rows
print("first 5 rows:")
print(df.head())
# Out:
# first 5 rows:
#    pokedex_number        name type_1  type_2  hp  attack  defense  sp_attack  \
# 0               1   Bulbasaur  Grass  Poison  45      49       49         65
# 1               2     Ivysaur  Grass  Poison  60      62       63         80
# 2               3    Venusaur  Grass  Poison  80      82       83        100
# 3               4  Charmander   Fire     NaN  39      52       43         60
# 4               5  Charmeleon   Fire     NaN  58      64       58         80
#
#    sp_defense  speed  ...      shape      egg_groups    habitat  growth_rate  \
# 0          65     45  ...  quadruped   monster|plant  grassland  medium-slow
# 1          80     60  ...  quadruped   monster|plant  grassland  medium-slow
# 2         100     80  ...  quadruped   monster|plant  grassland  medium-slow
# 3          50     65  ...    upright  monster|dragon   mountain  medium-slow
# 4          65     80  ...    upright  monster|dragon   mountain  medium-slow
#
#   capture_rate base_happiness           genus  evolution_chain_id  \
# 0           45             70    Seed Pokémon                   1
# 1           45             70    Seed Pokémon                   1
# 2           45             70    Seed Pokémon                   1
# 3           45             70  Lizard Pokémon                   2
# 4           45             70   Flame Pokémon                   2
#
#                                          flavor_text  \
# 0  A strange seed was planted on its back at birt...
# 1  When the bulb on its back grows large, it appe...
# 2  The plant blooms when it is absorbing solar en...
# 3  Obviously prefers hot places. When it rains, s...
# 4  When it swings its burning tail, it elevates t...
#
#                                           sprite_url
# 0  https://raw.githubusercontent.com/PokeAPI/spri...
# 1  https://raw.githubusercontent.com/PokeAPI/spri...
# 2  https://raw.githubusercontent.com/PokeAPI/spri...
# 3  https://raw.githubusercontent.com/PokeAPI/spri...
# 4  https://raw.githubusercontent.com/PokeAPI/spri...
#
# [5 rows x 31 columns]

# %%
#dataset information
print("\ndataset information:")
print(df.info())
# Out:
# dataset information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1350 entries, 0 to 1349
# Data columns (total 31 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   pokedex_number      1350 non-null   int64
#  1   name                1350 non-null   object
#  2   type_1              1350 non-null   object
#  3   type_2              765 non-null    object
#  4   hp                  1350 non-null   int64
#  5   attack              1350 non-null   int64
#  6   defense             1350 non-null   int64
#  7   sp_attack           1350 non-null   int64
#  8   sp_defense          1350 non-null   int64
#  9   speed               1350 non-null   int64
#  10  base_stat_total     1350 non-null   int64
#  11  height_m            1350 non-null   float64
#  12  weight_kg           1350 non-null   float64
#  13  base_experience     1302 non-null   float64
#  14  abilities           1325 non-null   object
#  15  hidden_ability      988 non-null    object
#  16  generation          1350 non-null   object
#  17  is_legendary        1350 non-null   bool
#  18  is_mythical         1350 non-null   bool
#  19  is_baby             1350 non-null   bool
#  20  color               1350 non-null   object
#  21  shape               1350 non-null   object
#  22  egg_groups          1350 non-null   object
#  23  habitat             520 non-null    object
#  24  growth_rate         1350 non-null   object
#  25  capture_rate        1350 non-null   int64
#  26  base_happiness      1350 non-null   int64
#  27  genus               1350 non-null   object
#  28  evolution_chain_id  1350 non-null   int64
#  29  flavor_text         1350 non-null   object
#  30  sprite_url          1290 non-null   object
# dtypes: bool(3), float64(3), int64(11), object(14)
# memory usage: 299.4+ KB
# None

# %%
#shape of dataset
print("\nrows and columns:")
print(df.shape)
# Out:
# rows and columns:
# (1350, 31)

# %%
#statistical summary
print("\nstatistical summary:")
print(df.describe())
# Out:
# statistical summary:
#        pokedex_number           hp       attack      defense    sp_attack  \
# count     1350.000000  1350.000000  1350.000000  1350.000000  1350.000000
# mean      2836.148148    71.671852    82.783704    76.194074    75.368148
# std       4135.531960    26.837396    32.350046    30.724283    33.989075
# min          1.000000     1.000000     5.000000     5.000000    10.000000
# 25%        338.250000    55.000000    60.000000    55.000000    50.000000
# 50%        675.500000    70.000000    80.000000    70.000000    69.000000
# 75%       1012.750000    85.000000   102.750000    95.000000    97.000000
# max      10325.000000   255.000000   190.000000   250.000000   216.000000
#
#         sp_defense        speed  base_stat_total     height_m    weight_kg  \
# count  1350.000000  1350.000000      1350.000000  1350.000000  1350.000000
# mean     74.095556    71.961481       452.074815     2.045259    99.171926
# std      27.801487    30.620661       122.462374     5.325712   195.368919
# min      20.000000     5.000000       175.000000     0.100000     0.000000
# 25%      54.000000    49.000000       340.000000     0.600000     9.425000
# 50%      70.000000    70.000000       475.000000     1.100000    32.700000
# 75%      90.000000    94.750000       530.000000     1.700000    85.425000
# max     250.000000   200.000000      1125.000000   100.000000  1000.000000
#
#        base_experience  capture_rate  base_happiness  evolution_chain_id
# count      1302.000000   1350.000000     1350.000000         1350.000000
# mean        161.943932     89.120741       59.396296          253.156296
# std          82.532554     74.419310       23.239064          163.129522
# min          36.000000      3.000000        0.000000            1.000000
# 25%          71.000000     45.000000       50.000000          102.250000
# 50%         165.000000     55.000000       70.000000          258.000000
# 75%         222.500000    120.000000       70.000000          392.000000
# max         608.000000    255.000000      140.000000          549.000000

# %%
#mean
print("\nmean:")
print(df.mean(numeric_only=True))
# Out:
# mean:
# pokedex_number        2836.148148
# hp                      71.671852
# attack                  82.783704
# defense                 76.194074
# sp_attack               75.368148
# sp_defense              74.095556
# speed                   71.961481
# base_stat_total        452.074815
# height_m                 2.045259
# weight_kg               99.171926
# base_experience        161.943932
# is_legendary             0.088889
# is_mythical              0.028148
# is_baby                  0.014074
# capture_rate            89.120741
# base_happiness          59.396296
# evolution_chain_id     253.156296
# dtype: float64

# %%
#median
print("\nMedian")
print(df.median(numeric_only=True))
# Out:
# Median
# pokedex_number        675.5
# hp                     70.0
# attack                 80.0
# defense                70.0
# sp_attack              69.0
# sp_defense             70.0
# speed                  70.0
# base_stat_total       475.0
# height_m                1.1
# weight_kg              32.7
# base_experience       165.0
# is_legendary            0.0
# is_mythical             0.0
# is_baby                 0.0
# capture_rate           55.0
# base_happiness         70.0
# evolution_chain_id    258.0
# dtype: float64

# %%
#mode
print("\nMode")
print(df.mode().iloc[0])
# Out:
# Mode
# pokedex_number                                                        1
# name                                                          Abomasnow
# type_1                                                            Water
# type_2                                                           Flying
# hp                                                                 60.0
# attack                                                            100.0
# defense                                                            70.0
# sp_attack                                                          50.0
# sp_defense                                                         50.0
# speed                                                              60.0
# base_stat_total                                                   600.0
# height_m                                                            0.3
# weight_kg                                                        1000.0
# base_experience                                                   270.0
# abilities                                                      levitate
# hidden_ability                                                telepathy
# generation                                                        gen-i
# is_legendary                                                      False
# is_mythical                                                       False
# is_baby                                                           False
# color                                                              blue
# shape                                                           upright
# egg_groups                                                       ground
# habitat                                                       grassland
# growth_rate                                                      medium
# capture_rate                                                       45.0
# base_happiness                                                     70.0
# genus                                                     Mouse Pokémon
# evolution_chain_id                                                 10.0
# flavor_text           When several of these POKéMON gather, their el...
# sprite_url            https://raw.githubusercontent.com/PokeAPI/spri...
# Name: 0, dtype: object

# %%
#standard deviation
print("\nstandard deviation:")
print(df.std(numeric_only=True))
# Out:
# standard deviation:
# pokedex_number        4135.531960
# hp                      26.837396
# attack                  32.350046
# defense                 30.724283
# sp_attack               33.989075
# sp_defense              27.801487
# speed                   30.620661
# base_stat_total        122.462374
# height_m                 5.325712
# weight_kg              195.368919
# base_experience         82.532554
# is_legendary             0.284689
# is_mythical              0.165457
# is_baby                  0.117840
# capture_rate            74.419310
# base_happiness          23.239064
# evolution_chain_id     163.129522
# dtype: float64

# %%
#variance
print("\nvariance:")
print(df.var(numeric_only=True))
# Out:
# variance:
# pokedex_number        1.710262e+07
# hp                    7.202458e+02
# attack                1.046525e+03
# defense               9.439816e+02
# sp_attack             1.155257e+03
# sp_defense            7.729227e+02
# speed                 9.376249e+02
# base_stat_total       1.499703e+04
# height_m              2.836321e+01
# weight_kg             3.816901e+04
# base_experience       6.811623e+03
# is_legendary          8.104769e-02
# is_mythical           2.737611e-02
# is_baby               1.388628e-02
# capture_rate          5.538234e+03
# base_happiness        5.400541e+02
# evolution_chain_id    2.661124e+04
# dtype: float64

# %%
#minimum values
print("\nminimum values:")
print(df.min(numeric_only=True))
# Out:
# minimum values:
# pokedex_number            1
# hp                        1
# attack                    5
# defense                   5
# sp_attack                10
# sp_defense               20
# speed                     5
# base_stat_total         175
# height_m                0.1
# weight_kg               0.0
# base_experience        36.0
# is_legendary          False
# is_mythical           False
# is_baby               False
# capture_rate              3
# base_happiness            0
# evolution_chain_id        1
# dtype: object

# %%
#maximum values
print("/nmaximum values:")
print(df.max(numeric_only=True))
# Out:
# /nmaximum values:
# pokedex_number         10325
# hp                       255
# attack                   190
# defense                  250
# sp_attack                216
# sp_defense               250
# speed                    200
# base_stat_total         1125
# height_m               100.0
# weight_kg             1000.0
# base_experience        608.0
# is_legendary            True
# is_mythical             True
# is_baby                 True
# capture_rate             255
# base_happiness           140
# evolution_chain_id       549
# dtype: object
