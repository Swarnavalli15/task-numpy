# %%
import pandas as pd

# %%
data = {
    "Popcorn": [1, 1, 0, 0, 1, 1, 0],
    "Soda": [1, 0, 1, 1, 1, 0, 0],
    "Age": [7, 12, 18, 35, 38, 50, 83],
    "Movie": [0, 0, 1, 1, 1, 0, 0]
}
df = pd.DataFrame(data)
print(df)
# Out:
#    Popcorn  Soda  Age  Movie
# 0        1     1    7      0
# 1        1     0   12      0
# 2        0     1   18      1
# 3        0     1   35      1
# 4        1     1   38      1
# 5        1     0   50      0
# 6        0     0   83      0

# %%
X = df[["Popcorn", "Soda", "Age"]]
y = df["Movie"]

print("Features:")
print(X)

print("\nTarget:")
print(y)
# Out:
# Features:
#    Popcorn  Soda  Age
# 0        1     1    7
# 1        1     0   12
# 2        0     1   18
# 3        0     1   35
# 4        1     1   38
# 5        1     0   50
# 6        0     0   83
#
# Target:
# 0    0
# 1    0
# 2    1
# 3    1
# 4    1
# 5    0
# 6    0
# Name: Movie, dtype: int64

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
model = DecisionTreeClassifier(criterion="gini")
model.fit(X, y)
# Out:
# DecisionTreeClassifier()

# %%
pred = [[0, 0, 88]]
prediction = model.predict(pred)
prediction
# Out:
# C:\Users\swarn\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([0], dtype=int64)

# %%
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10, 4))
plot_tree( model,feature_names=["Popcorn", "Soda", "Age"],class_names=["No", "Yes"],filled=True)
plt.show()
